# %%
## Import Libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
## Import Data
df = pd.read_csv("E_Commerce_Dataset.csv")

# %% [markdown]
# Explore Data

# %%
## Explore Data
df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
df.shape
# Out:
# (5630, 20)

# %%
df.isna().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#          CustomerID        Churn       Tenure     CityTier  WarehouseToHome  \
# count   5630.000000  5630.000000  5366.000000  5630.000000      5379.000000
# mean   52815.500000     0.168384    10.189899     1.654707        15.639896
# std     1625.385339     0.374240     8.557241     0.915389         8.531475
# min    50001.000000     0.000000     0.000000     1.000000         5.000000
# 25%    51408.250000     0.000000     2.000000     1.000000         9.000000
# 50%    52815.500000     0.000000     9.000000     1.000000        14.000000
# 75%    54222.750000     0.000000    16.000000     3.000000        20.000000
# max    55630.000000     1.000000    61.000000     3.000000       127.000000
#
#        HourSpendOnApp  NumberOfDeviceRegistered  SatisfactionScore  \
# count     5375.000000               5630.000000        5630.000000
# mean         2.931535                  3.688988           3.066785
# std          0.721926                  1.023999           1.380194
# ...

# %%
# Explore HourSpendOnApp by Target

sns.boxplot(data=df, x='Churn', y='HourSpendOnApp')
plt.show()

# %%
#Explore avg avgHourSpendOnApp by Target

df_by_target = df.groupby(by=['Churn']).agg(
          avgHourSpendOnApp=('HourSpendOnApp','mean')).reset_index()

sns.barplot(data=df_by_target, x='Churn', y='avgHourSpendOnApp')
plt.show()

# %%
# Explore Tenure by Target

sns.boxplot(data=df, x='Churn', y='Tenure')
plt.show()

# %%
#Explore avg Tenure by Target

df_by_target = df.groupby(by=['Churn']).agg(
          avgTenure=('Tenure','mean')).reset_index()

sns.barplot(data=df_by_target, x='Churn', y='avgTenure')
plt.show()

# %%
# Explore WarehouseToHome by Target

sns.boxplot(data=df, x='Churn', y='WarehouseToHome')
plt.show()

# %%
#Explore avg WarehouseToHome by Target

df_by_target = df.groupby(by=['Churn']).agg(
          avgWarehouseToHome=('WarehouseToHome','mean')).reset_index()

sns.barplot(data=df_by_target, x='Churn', y='avgWarehouseToHome')
plt.show()

# %%
# Explore NumberOfDeviceRegistered by Target

sns.boxplot(data=df, x='Churn', y='NumberOfDeviceRegistered')
plt.show()

# %%
#Explore avg NumberOfDeviceRegistered by Target

df_by_target = df.groupby(by=['Churn']).agg(
          avgNumberOfDeviceRegistered=('NumberOfDeviceRegistered','mean')).reset_index()

sns.barplot(data=df_by_target, x='Churn', y='avgNumberOfDeviceRegistered')
plt.show()

# %%
# Explore SatisfactionScore by Target

sns.boxplot(data=df, x='Churn', y='SatisfactionScore')
plt.show()

# %%
#Explore avg SatisfactionScore by Target

df_by_target = df.groupby(by=['Churn']).agg(
          avgSatisfactionScore=('SatisfactionScore','mean')).reset_index()

sns.barplot(data=df_by_target, x='Churn', y='avgSatisfactionScore')
plt.show()

# %%
# Explore NumberOfAddress by Target

sns.boxplot(data=df, x='Churn', y='NumberOfAddress')
plt.show()

# %%
#Explore avg NumberOfAddress by Target

df_by_target = df.groupby(by=['Churn']).agg(
          avgNumberOfAddress=('NumberOfAddress','mean')).reset_index()

sns.barplot(data=df_by_target, x='Churn', y='avgNumberOfAddress')
plt.show()

# %%
# Explore OrderAmountHikeFromlastYear by Target

sns.boxplot(data=df, x='Churn', y='OrderAmountHikeFromlastYear')
plt.show()

# %%
#Explore avg OrderAmountHikeFromlastYear by Target

df_by_target = df.groupby(by=['Churn']).agg(
          avgOrderAmountHikeFromlastYear=('OrderAmountHikeFromlastYear','mean')).reset_index()

sns.barplot(data=df_by_target, x='Churn', y='avgOrderAmountHikeFromlastYear')
plt.show()

# %%
# Explore CouponUsed by Target

sns.boxplot(data=df, x='Churn', y='CouponUsed')
plt.show()

# %%
#Explore avg CouponUsed by Target

df_by_target = df.groupby(by=['Churn']).agg(
          avgCouponUsed=('CouponUsed','mean')).reset_index()

sns.barplot(data=df_by_target, x='Churn', y='avgCouponUsed')
plt.show()

# %%
# Explore OrderCount by Target

sns.boxplot(data=df, x='Churn', y='OrderCount')
plt.show()

# %%
#Explore avg OrderCount by Target

df_by_target = df.groupby(by=['Churn']).agg(
          avgOrderCount=('OrderCount','mean')).reset_index()

sns.barplot(data=df_by_target, x='Churn', y='avgOrderCount')
plt.show()

# %%
# Explore DaySinceLastOrder by Target

sns.boxplot(data=df, x='Churn', y='DaySinceLastOrder')
plt.show()

# %%
#Explore avg DaySinceLastOrder by Target

df_by_target = df.groupby(by=['Churn']).agg(
          avgDaySinceLastOrder=('DaySinceLastOrder','mean')).reset_index()

sns.barplot(data=df_by_target, x='Churn', y='avgDaySinceLastOrder')
plt.show()

# %%
# Explore CashbackAmount by Target

sns.boxplot(data=df, x='Churn', y='CashbackAmount')
plt.show()

# %%
#Explore avg CashbackAmount by Target

df_by_target = df.groupby(by=['Churn']).agg(
          avgCashbackAmount=('CashbackAmount','mean')).reset_index()

sns.barplot(data=df_by_target, x='Churn', y='avgCashbackAmount')
plt.show()

# %%
#Explore No. of customers by Target

df_noCust_by_target = df.groupby(by=['Churn']).agg(
          no_customers=('Churn','count')).reset_index()

sns.barplot(data=df_noCust_by_target, x='Churn', y='no_customers')
plt.show()

# %%
#Explore PreferredLoginDevice by Target

df_PreferredLoginDevice_by_target = df.groupby(by=['PreferredLoginDevice', 'Churn']).agg(
                              no_customers=('Churn','count')).reset_index().pivot('PreferredLoginDevice', 'Churn', 'no_customers')

sns.heatmap(df_PreferredLoginDevice_by_target, annot=True, fmt='.0f')
# Out:
# <ipython-input-22-18e0dc8f50c5>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   no_customers=('Churn','count')).reset_index().pivot('PreferredLoginDevice', 'Churn', 'no_customers')
# <Axes: xlabel='Churn', ylabel='PreferredLoginDevice'>

# %%
#Explore CityTier by Target

df_CityTier_by_target = df.groupby(by=['CityTier', 'Churn']).agg(
                              no_customers=('Churn','count')).reset_index().pivot('CityTier', 'Churn', 'no_customers')

sns.heatmap(df_CityTier_by_target, annot=True, fmt='.0f')
# Out:
# <ipython-input-24-24e48d3345f1>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   no_customers=('Churn','count')).reset_index().pivot('CityTier', 'Churn', 'no_customers')
# <Axes: xlabel='Churn', ylabel='CityTier'>

# %%
#Explore PreferredPaymentMode by Target

df_PreferredPaymentMode_by_target = df.groupby(by=['PreferredPaymentMode', 'Churn']).agg(
                              no_customers=('Churn','count')).reset_index().pivot('PreferredPaymentMode', 'Churn', 'no_customers')

sns.heatmap(df_PreferredPaymentMode_by_target, annot=True, fmt='.0f')
# Out:
# <ipython-input-25-a29bb1d2a784>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   no_customers=('Churn','count')).reset_index().pivot('PreferredPaymentMode', 'Churn', 'no_customers')
# <Axes: xlabel='Churn', ylabel='PreferredPaymentMode'>

# %%
#Explore Gender by Target

df_Gender_by_target = df.groupby(by=['Gender', 'Churn']).agg(
                              no_customers=('Churn','count')).reset_index().pivot('Gender', 'Churn', 'no_customers')

sns.heatmap(df_Gender_by_target, annot=True, fmt='.0f')
# Out:
# <ipython-input-27-b14585e86cdb>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   no_customers=('Churn','count')).reset_index().pivot('Gender', 'Churn', 'no_customers')
# <Axes: xlabel='Churn', ylabel='Gender'>

# %%
#Explore PreferedOrderCat by Target

df_PreferedOrderCat_by_target = df.groupby(by=['PreferedOrderCat', 'Churn']).agg(
                              no_customers=('Churn','count')).reset_index().pivot('PreferedOrderCat', 'Churn', 'no_customers')

sns.heatmap(df_PreferedOrderCat_by_target, annot=True, fmt='.0f')
# Out:
# <ipython-input-29-200012334343>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   no_customers=('Churn','count')).reset_index().pivot('PreferedOrderCat', 'Churn', 'no_customers')
# <Axes: xlabel='Churn', ylabel='PreferedOrderCat'>

# %%
#Explore MaritalStatus by Target

df_MaritalStatus_by_target = df.groupby(by=['MaritalStatus', 'Churn']).agg(
                              no_customers=('Churn','count')).reset_index().pivot('MaritalStatus', 'Churn', 'no_customers')

sns.heatmap(df_MaritalStatus_by_target, annot=True, fmt='.0f')
# Out:
# <ipython-input-30-b1ea7c440308>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   no_customers=('Churn','count')).reset_index().pivot('MaritalStatus', 'Churn', 'no_customers')
# <Axes: xlabel='Churn', ylabel='MaritalStatus'>

# %%
#Explore Complain by Target

df_Complain_by_target = df.groupby(by=['Complain', 'Churn']).agg(
                              no_customers=('Churn','count')).reset_index().pivot('Complain', 'Churn', 'no_customers')

sns.heatmap(df_Complain_by_target, annot=True, fmt='.0f')
# Out:
# <ipython-input-31-cecd3bfd0b0a>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   no_customers=('Churn','count')).reset_index().pivot('Complain', 'Churn', 'no_customers')
# <Axes: xlabel='Churn', ylabel='Complain'>

# %% [markdown]
# Data Processing

# %%
cat_data = pd.DataFrame()

cat_data = pd.concat([cat_data, pd.get_dummies(df['PreferredPaymentMode'], prefix='PreferredPaymentMode')], axis=1)

df['PreferredPaymentMode'] = df['PreferredPaymentMode'].map({'Cash on Delivery':0, 'CC':1, 'COD':2, 'Credit Card':3,
                                                             'Debit Card':4, 'E wallet':5, 'UPI':6})

cat_data = pd.concat([cat_data, df['PreferredPaymentMode']], axis=1)
cat_data
# Out:
#       PreferredPaymentMode_CC  PreferredPaymentMode_COD  \
# 0                           0                         0
# 3                           0                         0
# 5                           0                         0
# 11                          0                         0
# 12                          0                         1
# ...                       ...                       ...
# 5624                        0                         0
# 5625                        0                         0
# 5627                        0                         0
# 5628                        0                         0
# 5629                        0                         0
#
#       PreferredPaymentMode_Cash on Delivery  PreferredPaymentMode_Credit Card  \
# 0                                         0                                 0
# 3                                         0                                 0
# ...

# %%
cat_data1 = pd.DataFrame()

cat_data1 = pd.concat([cat_data1, pd.get_dummies(df['PreferedOrderCat'], prefix='PreferedOrderCat')], axis=1)

df['PreferedOrderCat'] = df['PreferedOrderCat'].map({'Fashion':0, 'Grocery':1, 'Laptop & Accessory':2, 'Mobile':3,
                                                     'Mobile Phone':4, 'Others':5})

cat_data1 = pd.concat([cat_data1, df['PreferedOrderCat']], axis=1)
cat_data1
# Out:
#       PreferedOrderCat_Fashion  PreferedOrderCat_Grocery  \
# 0                            0                         0
# 3                            0                         0
# 5                            0                         0
# 11                           1                         0
# 12                           0                         0
# ...                        ...                       ...
# 5624                         0                         0
# 5625                         0                         0
# 5627                         0                         0
# 5628                         0                         0
# 5629                         0                         0
#
#       PreferedOrderCat_Laptop & Accessory  PreferedOrderCat_Mobile  \
# 0                                       1                        0
# 3                                       1                        0
# 5                                       0                        0
# ...

# %%
X = pd.concat([df[['WarehouseToHome', 'HourSpendOnApp', 'NumberOfDeviceRegistered',
                   'SatisfactionScore', 'NumberOfAddress', 'CashbackAmount', 'Complain']], cat_data, cat_data1], axis=1)
y = df['Churn']

# %% [markdown]
# Model Creation and Evaluation

# %%
# models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# model selection and evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report, roc_curve, auc

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40, random_state=42)

# %%
#Create Generic function to fit data and display results/predictions
def fit_evaluate(clf, X_train, X_test, y_train, y_test):
    # fit model to training data
    clf.fit(X_train, y_train)

    # make predictions for train data
    y_pred_train = clf.predict(X_train)

    # make predictions for test data
    y_pred_test = clf.predict(X_test)
    # print evaluation
    print(classification_report(y_test, y_pred_test))
    print('\nConfusion Matrix: \n')
    s = sns.heatmap(confusion_matrix(y_test, y_pred_test), annot=True, fmt='g', cmap='YlGnBu');
    s.set(xlabel='Predicted class', ylabel='True class')
    plt.show()

    fpr_train, tpr_train, _ = roc_curve(y_pred_train,  y_train)
    auc_train = roc_auc_score(y_pred_train, y_train)
    plt.plot(fpr_train,tpr_train, color='Blue', label='train: auc='+f'{auc_train:.2f}')

    fpr_test, tpr_test, _ = roc_curve(y_pred_test,  y_test)
    auc_test = roc_auc_score(y_pred_test, y_test)
    plt.plot(fpr_test,tpr_test, color='Red', label='test: auc='+f'{auc_test:.2f}')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.legend(loc=4)
    plt.show()

# %%
modelLR = LogisticRegression()
print('* Logistic regression * \n')
fit_evaluate(modelLR, X_train, X_test, y_train, y_test)
# Out:
# * Logistic regression *
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1274
#            1       0.60      0.22      0.33       236
#
#     accuracy                           0.86      1510
#    macro avg       0.74      0.60      0.62      1510
# weighted avg       0.83      0.86      0.83      1510
#
#
# Confusion Matrix:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
modelRF = RandomForestClassifier()
print('* Random Forest Classifier * \n')
fit_evaluate(modelRF, X_train, X_test, y_train, y_test)
# Out:
# * Random Forest Classifier *
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      1274
#            1       0.86      0.58      0.70       236
#
#     accuracy                           0.92      1510
#    macro avg       0.89      0.78      0.83      1510
# weighted avg       0.92      0.92      0.91      1510
#
#
# Confusion Matrix:

# %%
modelKNN = KNeighborsClassifier()
print('* K Nearest Neighbors Classifier * \n')
fit_evaluate(modelKNN, X_train, X_test, y_train, y_test)
# Out:
# * K Nearest Neighbors Classifier *
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      1274
#            1       0.38      0.17      0.23       236
#
#     accuracy                           0.83      1510
#    macro avg       0.62      0.56      0.57      1510
# weighted avg       0.78      0.83      0.80      1510
#
#
# Confusion Matrix:

# %% [markdown]
# SMOTE

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=0)

sm.fit(X_train, y_train)
X_train_SMOTE, y_train_SMOTE = sm.fit_resample(X_train, y_train)

# %%
modelLR = LogisticRegression()
print('* SMOTE and Logistic regression * \n')
fit_evaluate(modelLR, X_train_SMOTE, X_test, y_train_SMOTE, y_test)
# Out:
# * SMOTE and Logistic regression *
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85      1274
#            1       0.30      0.44      0.36       236
#
#     accuracy                           0.75      1510
#    macro avg       0.59      0.63      0.60      1510
# weighted avg       0.80      0.75      0.77      1510
#
#
# Confusion Matrix:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
modelRF = RandomForestClassifier()
print('* SMOTE and Random Forest Classifier * \n')
fit_evaluate(modelRF, X_train_SMOTE, X_test, y_train_SMOTE, y_test)
# Out:
# * SMOTE and Random Forest Classifier *
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94      1274
#            1       0.74      0.59      0.66       236
#
#     accuracy                           0.90      1510
#    macro avg       0.83      0.78      0.80      1510
# weighted avg       0.90      0.90      0.90      1510
#
#
# Confusion Matrix:

# %%
modelKNN = KNeighborsClassifier()
print('* SMOTE and K Nearest Neighbors Classifier * \n')
fit_evaluate(modelKNN, X_train_SMOTE, X_test, y_train_SMOTE, y_test)
# Out:
# * SMOTE and K Nearest Neighbors Classifier *
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.75      0.82      1274
#            1       0.32      0.65      0.43       236
#
#     accuracy                           0.73      1510
#    macro avg       0.62      0.70      0.63      1510
# weighted avg       0.83      0.73      0.76      1510
#
#
# Confusion Matrix:

# %% [markdown]
# Oversampling

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=0)
ros.fit(X_train, y_train)
X_oversampled, y_oversampled = ros.fit_resample(X_train, y_train)

# %% [markdown]
# Undersampling

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=0)
rus.fit(X_train, y_train)
X_undersampled, y_undersampled = rus.fit_resample(X_train, y_train)

# %% [markdown]
# XGBoost

# %%
import xgboost as xgb

modelXGB = xgb.XGBClassifier(objective='binary:logistic', eval_metric="auc")
print('* XGBoost Classifier * \n')
fit_evaluate(modelXGB, X_train, X_test, y_train, y_test)
# Out:
# * XGBoost Classifier *
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      1274
#            1       0.82      0.63      0.71       236
#
#     accuracy                           0.92      1510
#    macro avg       0.88      0.80      0.83      1510
# weighted avg       0.92      0.92      0.92      1510
#
#
# Confusion Matrix:

# %% [markdown]
# XGBoost - Hyperparameter Tuning

# %%
## building pipeline for hyperparameter tuning

from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, chi2

# Create a pipeline
pipe = Pipeline([
  ('fs', SelectKBest()),
  ('clf', xgb.XGBClassifier(objective='binary:logistic', scale_pos_weight=9))
])

# %%
## hyper parameter tuning - grid search

from sklearn.model_selection import KFold, GridSearchCV
from sklearn.metrics import accuracy_score, make_scorer
# Define our search space for grid search
search_space = [
  {
    'clf__n_estimators': [50, 100, 150, 200],
    'clf__learning_rate': [0.01, 0.1],
    'clf__max_depth': range(2, 4),
    'clf__colsample_bytree': [i/10.0 for i in range(2, 5)],
    'clf__gamma': [i/10.0 for i in range(3)],
    'fs__score_func': [chi2],
    'fs__k': [2],
  }
]
# Define cross validation
kfold = KFold(n_splits=5)
# AUC and accuracy as score
scoring = {'AUC':'roc_auc', 'Accuracy':make_scorer(accuracy_score), 'F1 score': 'f1_micro'}
# Define grid search
grid = GridSearchCV(
  pipe,
  param_grid=search_space,
  cv=kfold,
  scoring=scoring,
  refit='AUC',
  verbose=1,
  n_jobs=-1
)

# Fit grid search
xgb_model_clv_GS = grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits

# %%
print(xgb_model_clv_GS.best_params_)
# Out:
# {'clf__colsample_bytree': 0.2, 'clf__gamma': 0.2, 'clf__learning_rate': 0.1, 'clf__max_depth': 2, 'clf__n_estimators': 100, 'fs__k': 2, 'fs__score_func': <function chi2 at 0x7a1d8c640310>}

# %%
modelXGB = xgb.XGBClassifier(
 learning_rate =0.01,
 n_estimators=100,
 max_depth=2,
 min_child_weight=1,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.4,
 objective= 'binary:logistic',
 eval_metric="auc")
print('* XGBoost Classifier * \n')
fit_evaluate(modelXGB, X_train, X_test, y_train, y_test)
# Out:
# * XGBoost Classifier *
